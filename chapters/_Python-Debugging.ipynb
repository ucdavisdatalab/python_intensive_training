# %% [markdown]
# ##Debugging in Python

# %% [markdown]
# ##1. Use good coding practices

# %% [markdown]
# Write code in chunks

# %% [markdown]
# Write small well-named functions

# %% [markdown]
# Have your functions return results rather than just print results

# %% [markdown]
# Test results thoroughly and make sure they physically make sense

# %% [markdown]
# ## 2. Types of errors

# %% [markdown]
# Three major groups of errors:
# *   Syntax errors
# *   Runtime errors
# *   Logical errors

# %% [markdown]
# Syntax errors can be:
# *   leaving out a keyword
# *   leaving out a symbol, such as a colon, comma or brackets
# *   misspelling a keyword
# *   incorrect indentation

# %% [markdown]
# Syntax error example:

# %%
for i in range(0,20)
    print(i + 1)
# Out:
#   File "<ipython-input-1-33417fdb00ea>", line 1
#     for i in range(0,20)
#                         ^
# SyntaxError: invalid syntax

# %% [markdown]
# Runtime errors can be:
# *   division by zero
# *   performing an operation on incompatible types
# *   using an identifier which has not been defined
# *   accessing a list element, dictionary value or object attribute which doesn’t exist
# *   trying to access a file which doesn’t exist

# %% [markdown]
# Runtime error example:

# %%
a = 1
for x in range(a, b):
    print(x + 4)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-12a8aeebf4c8> in <module>()
#       1 a = 1
# ----> 2 for x in range(a, b):
#       3     print(x + 4)
#
# NameError: name 'b' is not defined

# %% [markdown]
# Logical errors can be:
#
#
# *   using the wrong variable name
# *   indenting a block to the wrong level
# *   using integer division instead of floating-point division
# *   getting operator precedence wrong
# *   making a mistake in a boolean expression
# *   off-by-one, and other numerical errors

# %%
x = float(input('Enter a number: '))
y = float(input('Enter a number: '))

z = (x+y)/2
print ('The average of the two numbers you have entered is:',z)
# Out:
# Enter a number: 4
# Enter a number: 5
# The average of the two numbers you have entered is: 4.5

# %% [markdown]
# ##3. When in doubt TYPE YOUR ERROR INTO GOOGLE (or stackexhange).

# %% [markdown]
# Google Colab has a convinient button to search for the errors on stack exchange

# %%
def func1(a, b):
    return a / b

# %%
def func2(x):
    a = x
    b = x - 1
    return func1(a, b)

# %%
func2(1)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-7-7cb498ea7ed1> in <module>()
# ----> 1 func2(1)
#
# <ipython-input-6-1b2fe74fbca6> in func2(x)
#       2     a = x
#       3     b = x - 1
# ----> 4     return func1(a, b)
#
# <ipython-input-5-60f4cafc236b> in func1(a, b)
#       1 def func1(a, b):
# ----> 2     return a / b
#
# ZeroDivisionError: division by zero

# %% [markdown]
# ##4. Add print() statements

# %% [markdown]
# When an error occurs, it can be useful to add print statements at individual steps

# %%
def average(numbers):
   if len(numbers) > 0:
         return sum(numbers) / len(numbers)

# %%
3*[0.1]
# Out:
# [0.1, 0.1, 0.1]

# %%
0.1 == average(3*[0.1])
# Out:
# False

# %%
def average(numbers):
   print('debug1:', numbers)
   if len(numbers) > 0:
         print('debug2:', sum(numbers))
         return sum(numbers) / len(numbers)

# %%
0.1 == average(3*[0.1])
# Out:
# debug1: [0.1, 0.1, 0.1]
# debug2: 0.30000000000000004
# False

# %% [markdown]
# ##5. Call functions with test cases

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Try the "edge cases": smallest, largest

# %%
def fib(n):
    if n == 0 or n == 1:
        return n
    else:
        return fib(n - 1) + fib(n - 2)

# %%
# test edge 0
obs = fib(0)
assert obs == 3

# test edge 1
obs = fib(1)
assert obs == 1

# test internal point
obs = fib(6)
assert obs == 8
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-15-b7197d8ff7db> in <module>()
#       1 # test edge 0
#       2 obs = fib(0)
# ----> 3 assert obs == 3
#       4
#       5 # test edge 1
#
# AssertionError:

# %% [markdown]
# ##6. Make sure to always go back and rerun cells

# %% [markdown]
# ##References:
#
# *   https://jupyter.brynmawr.edu/services/public/josh/BiolB115_2019/Lecture_notes/2019-03-04_Debugging_Testing.ipynb
# *   https://geek-university.com/python/syntax-and-logical-errors/
# *   http://carpentries-incubator.github.io/python-testing/06-edges/index.html
# *   https://docs.python.org/3/tutorial/errors.html
